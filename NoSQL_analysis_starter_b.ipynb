# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
pprint(db.establishments.find_one())
# Out:
# ['establishments']
# {'AddressLine1': 'St Marys Church Of England Primary School',
#  'AddressLine2': 'Warren Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'St Marys COE (aided) Primary School',
#  'BusinessType': 'School/college/university',
#  'BusinessTypeID': 7845,
#  'ChangesByServerID': 0,
#  'Distance': 4591.871474174837,
#  'FHRSID': 289353,
#  'LocalAuthorityBusinessID': 'PI/000002468',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6QH',
#  'RatingDate': '2016-09-13T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65fc8be526df2dd80396a076'),
#  'geocode': {'latitude': Decimal128('51.085797'),
#              'longitude': Decimal128('1.194762')},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289353',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find establishments with a hygiene score of 20
query = {"scores.Hygiene": 20}

# Count the number of documents matching the query
result_count = establishments.count_documents(query)
print("Number of establishments with a hygiene score of 20:", result_count)

# Display the details of the first matching establishment
first_establishment = establishments.find_one(query)
print("First establishment with a hygiene score of 20:")
pprint(first_establishment)
# Out:
# Number of establishments with a hygiene score of 20: 41
# First establishment with a hygiene score of 20:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('65fc8be526df2dd80396bba5'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'latitude': None,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'longitude': None,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert MongoDB query result to DataFrame
df = pd.DataFrame(establishments.find(query))

# Display number of rows in DataFrame
print("Number of rows in the DataFrame:", len(df))

# Display first 10 rows of DataFrame
print("First 10 rows of the DataFrame:")
print(df.head(10))
# Out:
# Number of rows in the DataFrame: 41
# First 10 rows of the DataFrame:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65fc8be526df2dd80396bba5   110681                  0
# 1  65fc8be526df2dd80396bf2a   612039                  0
# 2  65fc8be526df2dd80396c231   730933                  0
# 3  65fc8be526df2dd80396c41e   172735                  0
# 4  65fc8be526df2dd80396c42c   172953                  0
# 5  65fc8be526df2dd80396cdcd   512854                  0
# 6  65fc8be526df2dd80396cfec  1537089                  0
# 7  65fc8be626df2dd80396e51a   155648                  0
# 8  65fc8be626df2dd80396e95e  1012883                  0
# 9  65fc8be626df2dd80396f171   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode  RightToReply  \
# 0      {'longitude': 0.27694, 'latitude': 50.769705}
# 1     {'longitude': 1.278721, 'latitude': 51.857536}
# 2      {'longitude': 1.15927, 'latitude': 51.789429}
# 3      {'longitude': 0.10202, 'latitude': 50.770885}
# 4     {'longitude': 0.101446, 'latitude': 50.770724}
# 5     {'longitude': 0.736349, 'latitude': 51.541448}
# 6   {'longitude': 0.7121671, 'latitude': 51.5350065}
# 7     {'longitude': 0.602364, 'latitude': 51.591515}
# 8  {'longitude': 0.146449998021126, 'latitude': 5...
# 9      {'longitude': 0.462307, 'latitude': 51.57005}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links latitude longitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 1  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 2  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 3  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 4  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 5  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 6  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Count and print the number of establishments in London with a RatingValue >= 4
query = {'LocalAuthorityName': {'$regex':'London'}, "RatingValue": {"$gte": 4}}
print('Number of establishments:', establishments.count_documents(query))

# Print the details of the first matching establishment
print("First establishment details:")
print(establishments.find_one({"LocalAuthorityName": {'$regex':'London'}, "RatingValue": {"$gte": 4}}))
# Out:
# Number of establishments: 33
# First establishment details:
# {'_id': ObjectId('65fc8be626df2dd80396d5c3'), 'FHRSID': 621707, 'ChangesByServerID': 0, 'LocalAuthorityBusinessID': 'PI/000025307', 'BusinessName': "Charlie's", 'BusinessType': 'Other catering premises', 'BusinessTypeID': 7841, 'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks', 'AddressLine2': 'Sheppy Kent', 'AddressLine3': '', 'AddressLine4': '', 'PostCode': 'ME12', 'Phone': '', 'RatingValue': 4, 'RatingKey': 'fhrs_4_en-gb', 'RatingDate': '2021-10-18T00:00:00', 'LocalAuthorityCode': '508', 'LocalAuthorityName': 'City of London Corporation', 'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm', 'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk', 'scores': {'Hygiene': 5, 'Structural': 10, 'ConfidenceInManagement': 5}, 'SchemeType': 'FHRS', 'geocode': {'longitude': Decimal128('0.508551'), 'latitude': Decimal128('51.369321')}, 'RightToReply': '', 'Distance': 4627.439467780196, 'NewRatingPending': False, 'meta': {'dataSource': None, 'extractDate': '0001-01-01T00:00:00', 'itemCount': 0, 'returncode': None, 'totalCount': 0, 'totalPages': 0, 'pageSize': 0, 'pageNumber': 0}, 'links': [{'rel': 'self', 'href': 'https://api.ratings.food.gov.uk/establishments/621707'}], 'latitude': None, 'longitude': None}

# %%
# Convert result to Pandas DataFrame
df = pd.DataFrame(establishments.find({"LocalAuthorityName": {'$regex':'London'}, "RatingValue": {"$gte": 4}}))

# Display number of rows in DataFrame
print("Number of rows in the DataFrame:", len(df))

# Display first 10 rows of DataFrame
print("First 10 rows of the DataFrame:")
print(df.head(10))
# Out:
# Number of rows in the DataFrame: 33
# First 10 rows of the DataFrame:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65fc8be626df2dd80396d5c3   621707                  0
# 1  65fc8be626df2dd80396d8e6  1130836                  0
# 2  65fc8be626df2dd80396e434   293783                  0
# 3  65fc8be626df2dd80396f236  1315095                  0
# 4  65fc8be626df2dd80396f23a   294474                  0
# 5  65fc8be626df2dd80396f941   294900                  0
# 6  65fc8be626df2dd803971a4c   293756                  0
# 7  65fc8be626df2dd803971e15   878523                  0
# 8  65fc8be626df2dd803971e2f   294606                  0
# 9  65fc8be626df2dd803971e38   293772                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000016185                              WH Smith
# 9             PI/000002585         The Nuance Group (UK) Limited
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9        Retailers - other            4613
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                                London City Airport
# 9                  Duty Free Shop Passenger Terminal
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                               Tilbury     Charlton  ...
# 4                         Tilbury Essex               ...
# 5                                London               ...
# 6                                London               ...
# 7                                London               ...
# 8                     Silvertown London               ...
# 9  London City AirportRoyal DocksLondon               ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...       FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode  RightToReply  \
# 0     {'longitude': 0.508551, 'latitude': 51.369321}
# 1  {'longitude': 0.249255999922752, 'latitude': 5...
# 2     {'longitude': 0.561954, 'latitude': 51.543831}
# 3  {'longitude': 0.346336990594864, 'latitude': 5...
# 4     {'longitude': 0.346325, 'latitude': 51.464078}
# 5     {'longitude': 0.287555, 'latitude': 51.504071}
# 6     {'longitude': 0.069286, 'latitude': 51.501121}
# 7     {'longitude': 0.048006, 'latitude': 51.503733}
# 8  {'longitude': 0.0479655750095844, 'latitude': ...
# 9     {'longitude': 0.047966, 'latitude': 51.504112}
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.846754            False
# 4  4636.847650            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4649.173485            False
# 8  4649.188850            False
# 9  4649.188826            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links latitude longitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....     None      None
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
degree_search = 0.1
latitude = 51.5074
longitude = -0.1278

query = {
    'geocode.latitude': {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
    'geocode.longitude': {"$gte": longitude - degree_search, "$lte": longitude + degree_search},
    'RatingValue': 5
}

sort = [('Hygiene', 1)]
limit = 10

results = list(establishments.find().sort(sort).limit(limit))

pprint(results)
# Out:
# [{'AddressLine1': 'The Ship',
#   'AddressLine2': '23 The Stade',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'BusinessName': 'The Ships Galley',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4591.912144538092,
#   'FHRSID': 987206,
#   'LocalAuthorityBusinessID': 'PI/000075655',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'CT19 6AB',
#   'RatingDate': '2019-07-03T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65fc8be526df2dd80396a07f'),
#   'geocode': {'latitude': Decimal128('51.08084'),
#               'longitude': Decimal128('1.188537')},
#   'latitude': None,
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/987206',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'BusinessName': 'Little Rock',
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4591.914705329384,
#   'FHRSID': 1423242,
#   'LocalAuthorityBusinessID': 'PI/000078141',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': '',
#   'RatingDate': '2022-04-14T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65fc8be526df2dd80396a083'),
#   'geocode': {'latitude': Decimal128('51.0783519967076'),
#               'longitude': Decimal128('1.18590330311705')},
#   'latitude': None,
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1423242',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': None,
#              'Hygiene': None,
#              'Structural': None}},
#  {'AddressLine1': 'Wear Bay Road',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'BusinessName': 'Wear Bay Bowls Club',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4591.821311183521,
#   'FHRSID': 647177,
#   'LocalAuthorityBusinessID': 'PI/000041489',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'CT19 6PY',
#   'RatingDate': '2014-03-31T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65fc8be526df2dd80396a07a'),
#   'geocode': {'latitude': Decimal128('51.086058'),
#               'longitude': Decimal128('1.196408')},
#   'latitude': None,
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/647177',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 10, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'BusinessName': 'Docker',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4591.914705329384,
#   'FHRSID': 894592,
#   'LocalAuthorityBusinessID': 'PI/000074396',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': '',
#   'RatingDate': '2018-04-18T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65fc8be526df2dd80396a080'),
#   'geocode': {'latitude': Decimal128('51.0783519967076'),
#               'longitude': Decimal128('1.18590330311705')},
#   'latitude': None,
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/894592',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'Folkestone Harbour',
#   'AddressLine2': 'Harbour Approach Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'BusinessName': 'The Club Hut',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4591.914705329384,
#   'FHRSID': 1071930,
#   'LocalAuthorityBusinessID': 'PI/000076531',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': '',
#   'RatingDate': '2018-08-04T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65fc8be526df2dd80396a082'),
#   'geocode': {'latitude': Decimal128('51.0783519967076'),
#               'longitude': Decimal128('1.18590330311705')},
#   'latitude': None,
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1071930',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': '16 The Stade',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'BusinessName': 'Mariner',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4591.912144538092,
#   'FHRSID': 289560,
#   'LocalAuthorityBusinessID': 'PI/000039927',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'CT19 6AB',
#   'RatingDate': '2019-03-19T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65fc8be526df2dd80396a07e'),
#   'geocode': {'latitude': Decimal128('51.08084'),
#               'longitude': Decimal128('1.188537')},
#   'latitude': None,
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289560',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'St Marys Church Of England Primary School',
#   'AddressLine2': 'Warren Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'BusinessName': 'St Marys COE (aided) Primary School',
#   'BusinessType': 'School/college/university',
#   'BusinessTypeID': 7845,
#   'ChangesByServerID': 0,
#   'Distance': 4591.871474174837,
#   'FHRSID': 289353,
#   'LocalAuthorityBusinessID': 'PI/000002468',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'CT19 6QH',
#   'RatingDate': '2016-09-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65fc8be526df2dd80396a076'),
#   'geocode': {'latitude': Decimal128('51.085797'),
#               'longitude': Decimal128('1.194762')},
#   'latitude': None,
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289353',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': 'East Cliff Pavilion',
#   'AddressLine2': 'Wear Bay Road',
#   'AddressLine3': 'Folkestone',
#   'AddressLine4': 'Kent',
#   'BusinessName': 'The Pavilion',
#   'BusinessType': 'Restaurant/Cafe/Canteen',
#   'BusinessTypeID': 1,
#   'ChangesByServerID': 0,
#   'Distance': 4591.765489457773,
#   'FHRSID': 1043695,
#   'LocalAuthorityBusinessID': 'PI/000073616',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'CT19 6BL',
#   'RatingDate': '2018-04-04T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65fc8be526df2dd80396a078'),
#   'geocode': {'latitude': Decimal128('51.083812'),
#               'longitude': Decimal128('1.195625')},
#   'latitude': None,
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1043695',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '23 The Stade',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'BusinessName': 'The Ship',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4591.912144538092,
#   'FHRSID': 289352,
#   'LocalAuthorityBusinessID': 'PI/000002460',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'CT19 6AB',
#   'RatingDate': '2015-08-27T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65fc8be526df2dd80396a07d'),
#   'geocode': {'latitude': Decimal128('51.08084'),
#               'longitude': Decimal128('1.188537')},
#   'latitude': None,
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289352',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 5}},
#  {'AddressLine1': '1 The Stade',
#   'AddressLine2': 'Folkestone',
#   'AddressLine3': 'Kent',
#   'AddressLine4': '',
#   'BusinessName': 'Folkestone Trawlers Shop',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4591.912144538092,
#   'FHRSID': 344689,
#   'LocalAuthorityBusinessID': 'PI/000002095',
#   'LocalAuthorityCode': '188',
#   'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#   'LocalAuthorityName': 'Folkestone and Hythe',
#   'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'CT19 6AB',
#   'RatingDate': '2020-02-14T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65fc8be526df2dd80396a081'),
#   'geocode': {'latitude': Decimal128('51.08084'),
#               'longitude': Decimal128('1.188537')},
#   'latitude': None,
#   'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/344689',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}]

# %%
# Define latitude, longitude, search range, and rating value
latitude, longitude, degree_search, rating_value = 51.5074, -0.1278, 0.01, 5

# Define query, sort, and limit
query = {'geocode.latitude': {"$gte": latitude - degree_search, "$lte": latitude + degree_search},
         'geocode.longitude': {"$gte": longitude - degree_search, "$lte": longitude + degree_search},
         'RatingValue': rating_value}
sort = [('scores.Hygiene', 1)]
limit = 10

# Execute and print the results
print (list(establishments.find(query).sort(sort).limit(limit)))
# Out:
# []

# %%
from pprint import pprint

# Constants
degree_search = 0.01
latitude = 51.490142
longitude = 0.08384
rating_value = 5
limit = 5

# Query construction
query = {
    'geocode.latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search},
    'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search},
    'RatingValue': rating_value
}

# Sorting criteria
sort = [('scores.Hygiene', 1)]  # Sorting by hygiene score in ascending order

# Retrieve and print the results
results = establishments.find(query).sort(sort).limit(limit)
pprint(list(results))
# Out:
# [{'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65fc8be626df2dd803971403'),
#   'geocode': {'latitude': Decimal128('51.4873437'),
#               'longitude': Decimal128('0.09208')},
#   'latitude': None,
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '17 Lakedale Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Lumbini Grocery Ltd T/A Al-Iman',
#   'BusinessType': 'Retailers - other',
#   'BusinessTypeID': 4613,
#   'ChangesByServerID': 0,
#   'Distance': 4646.975587048333,
#   'FHRSID': 909912,
#   'LocalAuthorityBusinessID': 'PI/000201100',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1PP',
#   'RatingDate': '2020-10-20T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65fc8be626df2dd803971429'),
#   'geocode': {'latitude': Decimal128('51.4871632'),
#               'longitude': Decimal128('0.0916256')},
#   'latitude': None,
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/909912',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Plumstead Manor School Old Mill Road',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Plumstead Manor Nursery',
#   'BusinessType': 'Caring Premises',
#   'BusinessTypeID': 5,
#   'ChangesByServerID': 0,
#   'Distance': 4646.9740101340385,
#   'FHRSID': 695241,
#   'LocalAuthorityBusinessID': 'PI/000179088',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1QG',
#   'RatingDate': '2021-06-16T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65fc8be626df2dd803971421'),
#   'geocode': {'latitude': Decimal128('51.481517791748'),
#               'longitude': Decimal128('0.0859939977526665')},
#   'latitude': None,
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695241',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}},
#  {'AddressLine1': '144 - 146 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Iceland',
#   'BusinessType': 'Retailers - supermarkets/hypermarkets',
#   'BusinessTypeID': 7840,
#   'ChangesByServerID': 0,
#   'Distance': 4646.946071297699,
#   'FHRSID': 695223,
#   'LocalAuthorityBusinessID': 'PI/000178842',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-11-13T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65fc8be626df2dd8039713de'),
#   'geocode': {'latitude': Decimal128('51.4871482849121'),
#               'longitude': Decimal128('0.0924199968576431')},
#   'latitude': None,
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/695223',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}},
#  {'AddressLine1': 'Restaurant And Premises 107A Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Howe and Co Fish and Chips - Van 17',
#   'BusinessType': 'Mobile caterer',
#   'BusinessTypeID': 7846,
#   'ChangesByServerID': 0,
#   'Distance': 4646.95593107927,
#   'FHRSID': 1380578,
#   'LocalAuthorityBusinessID': '14425',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1SE',
#   'RatingDate': '2021-11-11T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('65fc8be626df2dd80397140b'),
#   'geocode': {'latitude': Decimal128('51.4875335693359'),
#               'longitude': Decimal128('0.0925370007753372')},
#   'latitude': None,
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/1380578',
#              'rel': 'self'}],
#   'longitude': None,
#   'meta': {'dataSource': None,
#            'extractDate': '0001-01-01T00:00:00',
#            'itemCount': 0,
#            'pageNumber': 0,
#            'pageSize': 0,
#            'returncode': None,
#            'totalCount': 0,
#            'totalPages': 0},
#   'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 0}}]

# %%
#Constants
degree_search = 0.01
latitude, longitude, rating_value, limit = 51.490142, 0.08384, 5, 5

#Query
query = {
    'geocode.latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search},
    'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search},
    'RatingValue': rating_value
}

#pandas DataFrame
df = pd.DataFrame(list(establishments.find(query).sort([('scores.Hygiene', 1)]).limit(limit)))

# Display the DataFrame
print(df)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65fc8be626df2dd803971403   694609                  0
# 1  65fc8be626df2dd803971429   909912                  0
# 2  65fc8be626df2dd803971421   695241                  0
# 3  65fc8be626df2dd8039713de   695223                  0
# 4  65fc8be626df2dd80397140b  1380578                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000116619                            Volunteer
# 1             PI/000201100      Lumbini Grocery Ltd T/A Al-Iman
# 2             PI/000179088              Plumstead Manor Nursery
# 3             PI/000178842                              Iceland
# 4                    14425  Howe and Co Fish and Chips - Van 17
#
#                             BusinessType  BusinessTypeID  \
# 0                      Pub/bar/nightclub            7843
# 1                      Retailers - other            4613
# 2                        Caring Premises               5
# 3  Retailers - supermarkets/hypermarkets            7840
# 4                         Mobile caterer            7846
#
#                                         AddressLine1 AddressLine2  \
# 0                    130 - 132 Plumstead High Street
# 1                                   17 Lakedale Road
# 2               Plumstead Manor School Old Mill Road
# 3                    144 - 146 Plumstead High Street
# 4  Restaurant And Premises 107A Plumstead High St...
#
#   AddressLine3  ...                                             scores  \
# 0    Plumstead  ...  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# 1    Plumstead  ...  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# 2    Plumstead  ...  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# 3    Plumstead  ...  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# 4    Plumstead  ...  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
#
#   SchemeType                                            geocode  RightToReply  \
# 0       FHRS     {'longitude': 0.09208, 'latitude': 51.4873437}
# 1       FHRS   {'longitude': 0.0916256, 'latitude': 51.4871632}
# 2       FHRS  {'longitude': 0.0859939977526665, 'latitude': ...
# 3       FHRS  {'longitude': 0.0924199968576431, 'latitude': ...
# 4       FHRS  {'longitude': 0.0925370007753372, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4646.965635            False
# 1  4646.975587            False
# 2  4646.974010            False
# 3  4646.946071            False
# 4  4646.955931            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links latitude longitude
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
#
# [5 rows x 30 columns]

# %%
import pandas as pd

# Constants
latitude, longitude, degree_search, rating_value, limit = 51.490142, 0.08384, 0.01, 5, 5

# Define the query
query = {
    'geocode.latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search},
    'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search},
    'RatingValue': rating_value
}

# Retrieve the results and convert to a pandas DataFrame
df = pd.DataFrame(list(establishments.find(query).sort([('scores.Hygiene', 1)]).limit(limit)))

# Display the number of rows and the first 10 rows of the DataFrame
print("Number of rows in the DataFrame:", len(df))
print("First 10 rows of the DataFrame:")
print(df.head(10))
# Out:
# Number of rows in the DataFrame: 5
# First 10 rows of the DataFrame:
#                         _id   FHRSID  ChangesByServerID  \
# 0  65fc8be626df2dd803971403   694609                  0
# 1  65fc8be626df2dd803971429   909912                  0
# 2  65fc8be626df2dd803971421   695241                  0
# 3  65fc8be626df2dd8039713de   695223                  0
# 4  65fc8be626df2dd80397140b  1380578                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000116619                            Volunteer
# 1             PI/000201100      Lumbini Grocery Ltd T/A Al-Iman
# 2             PI/000179088              Plumstead Manor Nursery
# 3             PI/000178842                              Iceland
# 4                    14425  Howe and Co Fish and Chips - Van 17
#
#                             BusinessType  BusinessTypeID  \
# 0                      Pub/bar/nightclub            7843
# 1                      Retailers - other            4613
# 2                        Caring Premises               5
# 3  Retailers - supermarkets/hypermarkets            7840
# 4                         Mobile caterer            7846
#
#                                         AddressLine1 AddressLine2  \
# 0                    130 - 132 Plumstead High Street
# 1                                   17 Lakedale Road
# 2               Plumstead Manor School Old Mill Road
# 3                    144 - 146 Plumstead High Street
# 4  Restaurant And Premises 107A Plumstead High St...
#
#   AddressLine3  ...                                             scores  \
# 0    Plumstead  ...  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# 1    Plumstead  ...  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# 2    Plumstead  ...  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
# 3    Plumstead  ...  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...
# 4    Plumstead  ...  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...
#
#   SchemeType                                            geocode  RightToReply  \
# 0       FHRS     {'longitude': 0.09208, 'latitude': 51.4873437}
# 1       FHRS   {'longitude': 0.0916256, 'latitude': 51.4871632}
# 2       FHRS  {'longitude': 0.0859939977526665, 'latitude': ...
# 3       FHRS  {'longitude': 0.0924199968576431, 'latitude': ...
# 4       FHRS  {'longitude': 0.0925370007753372, 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4646.965635            False
# 1  4646.975587            False
# 2  4646.974010            False
# 3  4646.946071            False
# 4  4646.955931            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links latitude longitude
# 0  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...     None      None
#
# [5 rows x 30 columns]
